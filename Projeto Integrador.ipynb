# %%
import pandas as pd
import numpy as np
import csv

# %%
dados = pd.read_csv(r'C:\Users\matth\Downloads\Trabalho\brasileirao_serie_a.csv')
#dados = csv.reader(open('C:\Users\aluno.laboratorio\Downloads\brasileirao_serie_a.csv', newline='', encoding='utf-8'))

# %%
#
dados.head(1000)
# Out:
#      ano_campeonato        data horario  rodada  \
# 0              2003  2003-03-29   08:00       1
# 1              2003  2003-03-29   08:00       1
# 2              2003  2003-03-30   09:00       1
# 3              2003  2003-03-30   09:00       1
# 4              2003  2003-03-30   09:00       1
# ..              ...         ...     ...     ...
# 995            2005  2005-06-19   11:10       8
# 996            2005  2005-06-19   11:10       8
# 997            2005  2005-06-19   11:10       8
# 998            2005  2005-06-19   11:10       8
# 999            2005  2005-06-19   11:10       8
#
#                                  estadio arbitro  publico  publico_max  \
# 0     Estádio Brinco de Ouro da Princesa     NaN      NaN          NaN
# 1                       Arena da Baixada     NaN      NaN          NaN
# 2         Estádio Jornalista Mário Filho     NaN      NaN          NaN
# 3              Estádio de Hailé Pinheiro     NaN      NaN          NaN
# 4                      Estádio Beira-Rio     NaN      NaN          NaN
# ..                                   ...     ...      ...          ...
# 995      Estádio Cícero Pompeu de Toledo     NaN      NaN          NaN
# 996  Estádio Major Antônio Couto Pereira     NaN      NaN          NaN
# 997       Estádio Jornalista Mário Filho     NaN      NaN          NaN
# 998               Estádio Alfredo Jaconi     NaN      NaN          NaN
# 999   Estádio Governador Plácido Castelo     NaN      NaN          NaN
#
#           time_man       time_vis  ... chutes_bola_parada_man  \
# 0          Guarani  Vasco da Gama  ...                    NaN
# 1      Atlético-PR         Grêmio  ...                    NaN
# 2         Flamengo    Coritiba FC  ...                    NaN
# 3         Goiás EC    Paysandu SC  ...                    NaN
# 4    Internacional    Ponte Preta  ...                    NaN
# ..             ...            ...  ...                    ...
# 995      São Paulo       Botafogo  ...                    NaN
# 996    Coritiba FC         Paraná  ...                    NaN
# 997     Fluminense  Internacional  ...                    NaN
# 998      Juventude       Cruzeiro  ...                    NaN
# 999      Fortaleza      Santos FC  ...                    NaN
#
#     chutes_bola_parada_vis  defesas_man  defesas_vis  impedimentos_man  \
# 0                      NaN          NaN          NaN               NaN
# 1                      NaN          NaN          NaN               NaN
# 2                      NaN          NaN          NaN               NaN
# 3                      NaN          NaN          NaN               NaN
# 4                      NaN          NaN          NaN               NaN
# ..                     ...          ...          ...               ...
# 995                    NaN          NaN          NaN               NaN
# 996                    NaN          NaN          NaN               NaN
# 997                    NaN          NaN          NaN               NaN
# 998                    NaN          NaN          NaN               NaN
# 999                    NaN          NaN          NaN               NaN
#
#      impedimentos_vis  chutes_man  chutes_vis  chutes_fora_man  \
# 0                 NaN         NaN         NaN              NaN
# 1                 NaN         NaN         NaN              NaN
# 2                 NaN         NaN         NaN              NaN
# 3                 NaN         NaN         NaN              NaN
# 4                 NaN         NaN         NaN              NaN
# ..                ...         ...         ...              ...
# 995               NaN         NaN         NaN              NaN
# 996               NaN         NaN         NaN              NaN
# 997               NaN         NaN         NaN              NaN
# 998               NaN         NaN         NaN              NaN
# 999               NaN         NaN         NaN              NaN
#
#      chutes_fora_vis
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 995              NaN
# 996              NaN
# 997              NaN
# 998              NaN
# 999              NaN
#
# [1000 rows x 36 columns]

# %%
dados.tail()
# Out:
#       ano_campeonato        data horario  rodada  \
# 7025            2020  2021-02-26   01:30      38
# 7026            2020  2021-02-26   01:30      38
# 7027            2020  2021-02-26   01:30      38
# 7028            2020  2021-02-26   01:30      38
# 7029            2020  2021-02-26   01:30      38
#
#                                  estadio                     arbitro  publico  \
# 7025                   Estádio Beira-Rio              Wilton Sampaio      0.0
# 7026                    Arena Fonte Nova  Paulo Roberto Alves Júnior      0.0
# 7027                    Arena da Baixada   Flavio Rodrigues de Souza      0.0
# 7028  Estádio Governador Plácido Castelo               Raphael Claus      0.0
# 7029             Estádio Antonio Accioly         Edina Alves Batista      0.0
#
#       publico_max       time_man      time_vis  ... chutes_bola_parada_man  \
# 7025      56000.0  Internacional   Corinthians  ...                   13.0
# 7026      55000.0       EC Bahia     Santos FC  ...                   13.0
# 7027      42372.0   Athletico-PR  Sport Recife  ...                    9.0
# 7028      60326.0       Ceará SC      Botafogo  ...                    4.0
# 7029      13000.0    Atlético-GO   Coritiba FC  ...                    9.0
#
#      chutes_bola_parada_vis  defesas_man  defesas_vis  impedimentos_man  \
# 7025                   12.0          1.0          5.0               6.0
# 7026                   11.0          5.0          3.0               2.0
# 7027                   15.0          4.0          6.0               2.0
# 7028                    5.0          2.0          4.0               0.0
# 7029                    8.0          0.0          4.0               1.0
#
#       impedimentos_vis  chutes_man  chutes_vis  chutes_fora_man  \
# 7025               1.0        16.0         6.0              6.0
# 7026               1.0        16.0        15.0              8.0
# 7027               2.0        18.0        15.0              8.0
# 7028               2.0        12.0        17.0              5.0
# 7029               1.0        18.0         9.0              8.0
#
#       chutes_fora_vis
# 7025              2.0
# 7026              6.0
# 7027              6.0
# 7028              8.0
# 7029              8.0
#
# [5 rows x 36 columns]

# %%
print(dados.shape) #Exibe a forma do ndarray. Nº de linhas e Nº de colunas, respectivamente

print(dados.ndim) #Exibe o número de dimensões da estrutura
# Out:
# (7030, 36)
# 2

# %%
tabela_time = set(dados['time_man'])

# %%
print(tabela_time)
# Out:
# {'Palmeiras', 'Joinville-SC', 'Santa Cruz', 'Barueri', 'Internacional', 'Cruzeiro', 'Corinthians', 'Paysandu SC', 'Goiás EC', 'Brasiliense-DF', 'Athletico-PR', 'Grêmio', 'CSA', 'EC Vitória', 'Fluminense', 'Fortaleza', 'RB Bragantino', 'América-RN', 'Náutico', 'Atlético-MG', 'Portuguesa', 'São Caetano', 'Ponte Preta', 'Chapecoense', 'Coritiba FC', 'Botafogo', 'Santos FC', 'América-MG', 'Vasco da Gama', 'Flamengo', 'Figueirense FC', 'Paraná', 'Santo André', 'São Paulo', 'Ceará SC', 'Atlético-PR', 'Ipatinga FC', 'Criciúma EC', 'EC Bahia', 'Avaí FC', 'Sport Recife', 'Atlético-GO', 'Guarani', 'Juventude'}

# %%
df_tabela_time = pd.DataFrame(tabela_time)

# %%
df_tabela_timeV2 = df_tabela_time.rename(columns={0:'Times'})

# %%
df_tabela_timeV2.head(50)
# Out:
#              Times
# 0        Palmeiras
# 1     Joinville-SC
# 2       Santa Cruz
# 3          Barueri
# 4    Internacional
# 5         Cruzeiro
# 6      Corinthians
# 7      Paysandu SC
# 8         Goiás EC
# 9   Brasiliense-DF
# 10    Athletico-PR
# 11          Grêmio
# 12             CSA
# 13      EC Vitória
# 14      Fluminense
# 15       Fortaleza
# 16   RB Bragantino
# 17      América-RN
# 18         Náutico
# 19     Atlético-MG
# 20      Portuguesa
# 21     São Caetano
# 22     Ponte Preta
# 23     Chapecoense
# 24     Coritiba FC
# 25        Botafogo
# 26       Santos FC
# 27      América-MG
# 28   Vasco da Gama
# 29        Flamengo
# 30  Figueirense FC
# 31          Paraná
# 32     Santo André
# 33       São Paulo
# 34        Ceará SC
# 35     Atlético-PR
# 36     Ipatinga FC
# 37     Criciúma EC
# 38        EC Bahia
# 39         Avaí FC
# 40    Sport Recife
# 41     Atlético-GO
# 42         Guarani
# 43       Juventude

# %%
df_tabela_timeV3['indice'] = df_tabela_timeV2.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/243059924.py in <module>
# ----> 1 df_tabela_timeV3['indice'] = df_tabela_timeV2.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
lista = np.arange(len(df_tabela_timeV2['Times']))

# %%
df_tabela_timeV2.insert(1,"indice",lista)

# %%
df_tabela_timeV2.head(50)
# Out:
#              Times  indice
# 0        Palmeiras       0
# 1     Joinville-SC       1
# 2       Santa Cruz       2
# 3          Barueri       3
# 4    Internacional       4
# 5         Cruzeiro       5
# 6      Corinthians       6
# 7      Paysandu SC       7
# 8         Goiás EC       8
# 9   Brasiliense-DF       9
# 10    Athletico-PR      10
# 11          Grêmio      11
# 12             CSA      12
# 13      EC Vitória      13
# 14      Fluminense      14
# 15       Fortaleza      15
# 16   RB Bragantino      16
# 17      América-RN      17
# 18         Náutico      18
# 19     Atlético-MG      19
# 20      Portuguesa      20
# 21     São Caetano      21
# 22     Ponte Preta      22
# 23     Chapecoense      23
# 24     Coritiba FC      24
# 25        Botafogo      25
# 26       Santos FC      26
# 27      América-MG      27
# 28   Vasco da Gama      28
# 29        Flamengo      29
# 30  Figueirense FC      30
# 31          Paraná      31
# 32     Santo André      32
# 33       São Paulo      33
# 34        Ceará SC      34
# 35     Atlético-PR      35
# 36     Ipatinga FC      36
# 37     Criciúma EC      37
# 38        EC Bahia      38
# 39         Avaí FC      39
# 40    Sport Recife      40
# 41     Atlético-GO      41
# 42         Guarani      42
# 43       Juventude      43

# %%
dados_v2 = pd.merge(dados,df_tabela_timeV2, how = 'left', on ='time_man')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3096/469656357.py in <module>
# ----> 1 dados_v2 = pd.merge(dados,df_tabela_timeV2, how = 'left', on ='time_man')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'time_man'
